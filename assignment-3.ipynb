# %%
#Programming Task - 2 (For Advance(EDA) Python Programmers)

# %%
#Defanging an IP Address

class Solution:
    def defangIPaddr(self, address: str) -> str:
        return address.replace(".", "[.]")
address = input("Enter IPv4 address: ")
sol = Solution()
result = sol.defangIPaddr(address)
print("Defanged IP address:", result)
# Out:
# Defanged IP address: 1[.]1[.]1[.]1

# %%
#Find Numbers with Even Number of Digits

class Solution:
    def findNumbers(self, nums: list[int]) -> int:
        count = 0
        for num in nums:
            if len(str(num)) % 2 == 0:
                count += 1
        return count
nums = list(map(int, input("Enter numbers separated by spaces: ").split()))
sol = Solution()
result = sol.findNumbers(nums)
print("Count of numbers with even number of digits: ", result)
# Out:
# Count of numbers with even number of digits:  2

# %%
#Number of Good Pairs

class Solution:
    def numIdenticalPairs(self, nums: list[int]) -> int:
        count = 0
        for i in range(len(nums)):
            for j in range(i + 1, len(nums)):
                if nums[i] == nums[j]:
                    count += 1
        return count
nums = list(map(int, input("Enter numbers separated by spaces: ").split()))
sol = Solution()
result = sol.numIdenticalPairs(nums)
print("Number of good pairs: ", result)
# Out:
# Number of good pairs:  4

# %%
#How Many Numbers Are Smaller Than the Current Number

class Solution:
    def smallerNumbersThanCurrent(self, nums: list[int]) -> list[int]:
        result = []
        for i in range(len(nums)):
            count = 0
            for j in range(len(nums)):
                if nums[j] < nums[i]:
                    count += 1
            result.append(count)
        return result
nums = list(map(int, input("Enter numbers separated by spaces: ").split()))
sol = Solution()
result = sol.smallerNumbersThanCurrent(nums)
print("Numbers smaller than the current number: ", result)
# Out:
# Numbers smaller than the current number:  [4, 0, 1, 1, 3]

# %%
#Subtract the Product and Sum of Digits of an Integer

class Solution:
    def subtractProductAndSum(self, n: int) -> int:
        product = 1
        sum = 0
        for digit in str(n):
            product *= int(digit)
            sum += int(digit)
        return product - sum
n = int(input("Enter an integer: "))
sol = Solution()
result = sol.subtractProductAndSum(n)
print("Subtract the product and sum of digits: ", result)
# Out:
# Subtract the product and sum of digits:  15

# %%
#XOR Operation in an Array

class Solution:
    def xorOperation(self, n: int, start: int) -> int:
        result = 0
        for i in range(n):
            result ^= (start + 2 * i)
        return result
n, start = map(int, input("Enter n and start separated by space: ").split())
sol = Solution()
result = sol.xorOperation(n, start)
print("XOR operation result: ", result)
# Out:
# XOR operation result:  8

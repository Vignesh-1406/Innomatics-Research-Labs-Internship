# %%
#Programming Task - 3 (For Advance(EDA) Python Programers)

# %%
#Maximum Product of Two Elements in an Array

class Solution:
    def maxProduct(self, nums: list[int]) -> int:
        nums.sort()
        return (nums[-1] - 1) * (nums[-2] - 1)
nums = list(map(int, input("Enter the numbers separated by spaces: ").split()))
solution = Solution()
result = solution.maxProduct(nums)
print("Maximum product:", result)
# Out:
# Maximum product: 12

# %%
#Count Number of Teams

class Solution:
    def numTeams(self, rating: list[int]) -> int:
        n = len(rating)
        count = 0
        for j in range(n):
            left_smaller = left_greater = 0
            right_smaller = right_greater = 0
            for i in range(j):
                if rating[i] < rating[j]:
                    left_smaller += 1
                else:
                    left_greater += 1
            for k in range(j + 1, n):
                if rating[k] > rating[j]:
                    right_greater += 1
                else:
                    right_smaller += 1
            count += (left_smaller * right_greater) + (left_greater * right_smaller)
        return count
rating = list(map(int, input("Enter the ratings separated by spaces: ").split()))
solution = Solution()
result = solution.numTeams(rating)
print("Number of teams:", result)
# Out:
# Number of teams: 3

# %%
#Number of Students Doing Homework at a Given Time

class Solution:
    def busyStudent(self, startTime: list[int], endTime: list[int], queryTime: int) -> int:
        count = 0
        for i in range(len(startTime)):
            if startTime[i] <= queryTime <= endTime[i]:
                count += 1
        return count
startTime = list(map(int, input("Enter the start times separated by spaces: ").split()))
endTime = list(map(int, input("Enter the end times separated by spaces: ").split()))
queryTime = int(input("Enter the query time: "))
sol = Solution()
result = sol.busyStudent(startTime, endTime, queryTime)
print("Number of students doing homework at query time:", result)
# Out:
# Number of students doing homework at query time: 1

# %%
#Number of Steps to Reduce a Number to Zero

class Solution:
    def numberOfSteps(self, num: int) -> int:
        steps = 0
        while num > 0:
            if num % 2 == 0:
                num //= 2
            else:
                num -= 1
            steps += 1
        return steps
num = int(input("Enter a non-negative integer: "))
solution = Solution()
result = solution.numberOfSteps(num)
print("Number of steps to reduce to zero:", result)
# Out:
# Number of steps to reduce to zero: 6

# %%
#Counting Bits

class Solution:
    def countBits(self, n: int) -> list[int]:
        result = []
        for i in range(n + 1):
            result.append(bin(i).count('1'))
        return result
n = int(input("Enter a non-negative integer: "))
solution = Solution()
result = solution.countBits(n)
print("Counting bits from 0 to", n, ":", result)
# Out:
# Counting bits from 0 to 5 : [0, 1, 1, 2, 1, 2]
